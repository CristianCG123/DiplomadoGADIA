# %% [markdown]
# <a href="https://colab.research.google.com/github/CristianCG123/DiplomadoGADIA/blob/main/LIBRERIAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# MANIPULACION DE DATOS
import pandas as pd

#visualizacion de datos

import matplotlib.pyplot as plt

#datos

import seaborn as sns

#datos

import numpy as np

# %%
#conectarse a la fuente de datos

salarios = pd.read_csv("/content/sample_data/Salary_Data (1).csv")
salarios.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
#revisar columnas que componen el dataset

salarios.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
#describir
salarios.describe(
)
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
#cambiar nombre de columnas
salarios.rename(columns={"YearsExperience" : "Años de experiencia"})
salarios.rename(columns={"Salary":"Salario"})
# Out:
#     Años de experiencia   Salario
# 0                   1.1   39343.0
# 1                   1.3   46205.0
# 2                   1.5   37731.0
# 3                   2.0   43525.0
# 4                   2.2   39891.0
# 5                   2.9   56642.0
# 6                   3.0   60150.0
# 7                   3.2   54445.0
# 8                   3.2   64445.0
# 9                   3.7   57189.0
# 10                  3.9   63218.0
# 11                  4.0   55794.0
# 12                  4.0   56957.0
# 13                  4.1   57081.0
# 14                  4.5   61111.0
# 15                  4.9   67938.0
# 16                  5.1   66029.0
# 17                  5.3   83088.0
# 18                  5.9   81363.0
# 19                  6.0   93940.0
# 20                  6.8   91738.0
# 21                  7.1   98273.0
# 22                  7.9  101302.0
# 23                  8.2  113812.0
# 24                  8.7  109431.0
# 25                  9.0  105582.0
# ...

# %%
 #extraer columna

anios_de_experiencia = salarios["Años de experiencia"]

# %% [markdown]
# ## regrecion lineal

# %%
x=salarios["Años de experiencia"]
y=salarios["Salario"]
plt.scatter(x,y,color = "red")
#titulo del  grafico
plt.title("Salario vs Años de experiencia")

#eje X
plt.xlabel("Años de Experiencia")
#eje y

plt.ylabel("Salario")

plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
regresion = LinearRegression

regresion.fit(x,y)
#prediccion.

Y_pred = regresion.predict(x)
